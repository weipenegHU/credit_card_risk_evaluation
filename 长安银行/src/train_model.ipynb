# %%
import pandas as pd
import numpy as np
from utils import peek
import config
import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV, learning_curve, LearningCurveDisplay, StratifiedKFold
import pickle
import optuna
import xgboost as xgb
from xgboost import XGBClassifier
import lightgbm as lgbm
from catboost import CatBoostClassifier, Pool
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore", module="optuna")
warnings.filterwarnings("ignore", module="lightgbm")

# %% [markdown]
# ## Baseline

# %%
train = pd.read_csv(config.TRAIN)

# %%
def train_lr_cv(X, y, param, verbose=True):
    clf = LogisticRegression(**param)
    cvs = []
    for fold in range(0, 5):
        train_x = X.query(f'fold != {fold}').drop(columns='fold')
        train_y = y[train_x.index]
        valid_x = X.query(f'fold == {fold}').drop(columns='fold')
        valid_y = y[valid_x.index]
        valid_score = clf.fit(train_x, train_y).predict_proba(valid_x)[:, 1]
        cvs.append(roc_auc_score(valid_y, valid_score))
    
    if verbose:
        print("five fold auc:", *cvs, sep=", ")
        print("mean auc:", np.mean(cvs))
        
    return cvs

# %%
def train_lr(X, y, param):
    clf = LogisticRegression(**param)
    clf.fit(X, y)
    return clf

# %%
param = {'C':1, 'max_iter':30, 'solver':'newton-cg', 'class_weight':'balanced'}
cvs = train_lr_cv(train.drop('order_status_key', axis=1), train['order_status_key'], param)
# Out:
# five fold auc:, 0.7512034198678033, 0.7362594597183638, 0.749833558254611, 0.7793312340680761, 0.7639389569814949
# mean auc: 0.7561133257780698

# %%
param = {'C':1, 'max_iter':20, 'solver':'newton-cg', 'class_weight':'balanced'}
model = train_lr(train.drop(['order_status_key', 'fold'], axis=1), train['order_status_key'], param)

# %%
pickle.dump(model, open(config.BASELINE, "wb"))

# %% [markdown]
# ## Random Forest

# %%
train = pd.read_csv(config.TRAIN2)

# %%
# tune using optuna
clf = RandomForestClassifier(random_state=42, class_weight="balanced", criterion='entropy', n_jobs=-1)
param_distributions = {
    'n_estimators':optuna.distributions.IntDistribution(100, 500, log=True),
    'max_depth':optuna.distributions.IntDistribution(5, 10, step=1), 
    'min_samples_split':optuna.distributions.IntDistribution(5, 50, step=5), 
    'min_samples_leaf':optuna.distributions.IntDistribution(1, 10, step=1),
    'max_features':optuna.distributions.FloatDistribution(0.2, 0.6, step=0.1),
    'max_samples':optuna.distributions.FloatDistribution(0.4, 0.7, step=0.1)
}
optuna_search = optuna.integration.OptunaSearchCV(clf, param_distributions, n_trials=100, scoring="roc_auc", n_jobs=-1)
X, y = train.drop(['order_status_key', 'fold'], axis=1), train['order_status_key']
optuna_search.fit(X, y)
y_pred = optuna_search.predict(X)
# Out:
# /tmp/ipykernel_2449652/2201020517.py:11: ExperimentalWarning: OptunaSearchCV is experimental (supported from v0.17.0). The interface can change in the future.
#   optuna_search = optuna.integration.OptunaSearchCV(clf, param_distributions, n_trials=100, scoring="roc_auc", n_jobs=-1)
# [I 2023-05-10 11:47:25,605] A new study created in memory with name: no-name-5a398565-1abb-4ea7-b981-818c061e1ba4
# [I 2023-05-10 11:48:13,255] Trial 23 finished with value: 0.7510565192904775 and parameters: {'n_estimators': 117, 'max_depth': 6, 'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 0.4, 'max_samples': 0.4}. Best is trial 23 with value: 0.7510565192904775.
# [I 2023-05-10 11:48:13,744] Trial 12 finished with value: 0.7538933504344463 and parameters: {'n_estimators': 106, 'max_depth': 7, 'min_samples_split': 35, 'min_samples_leaf': 1, 'max_features': 0.2, 'max_samples': 0.7}. Best is trial 12 with value: 0.7538933504344463.
# [I 2023-05-10 11:48:13,981] Trial 34 finished with value: 0.7538975469108851 and parameters: {'n_estimators': 106, 'max_depth': 10, 'min_samples_split': 35, 'min_samples_leaf': 9, 'max_features': 0.2, 'max_samples': 0.6000000000000001}. Best is trial 34 with value: 0.7538975469108851.
# [I 2023-05-10 11:48:14,622] Trial 18 finished with value: 0.7523709618507743 and parameters: {'n_estimators': 156, 'max_depth': 10, 'min_samples_split': 35, 'min_samples_leaf': 10, 'max_features': 0.5, 'max_samples': 0.5}. Best is trial 34 with value: 0.7538975469108851.
# [I 2023-05-10 11:48:15,022] Trial 33 finished with value: 0.753130288240959 and parameters: {'n_estimators': 152, 'max_depth': 10, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': 0.30000000000000004, 'max_samples': 0.4}. Best is trial 34 with value: 0.7538975469108851.
# [I 2023-05-10 11:48:15,526] Trial 2 finished with value: 0.7526868682200333 and parameters: {'n_estimators': 117, 'max_depth': 9, 'min_samples_split': 45, 'min_samples_leaf': 10, 'max_features': 0.4, 'max_samples': 0.6000000000000001}. Best is trial 34 with value: 0.7538975469108851.
# [I 2023-05-10 11:48:15,872] Trial 11 finished with value: 0.7519108800089332 and parameters: {'n_estimators': 137, 'max_depth': 9, 'min_samples_split': 35, 'min_samples_leaf': 5, 'max_features': 0.5, 'max_samples': 0.6000000000000001}. Best is trial 34 with value: 0.7538975469108851.
# [I 2023-05-10 11:48:16,288] Trial 21 finished with value: 0.751427788132186 and parameters: {'n_estimators': 146, 'max_depth': 5, 'min_samples_split': 30, 'min_samples_leaf': 8, 'max_features': 0.30000000000000004, 'max_samples': 0.4}. Best is trial 34 with value: 0.7538975469108851.
# [I 2023-05-10 11:48:16,430] Trial 7 finished with value: 0.7537847638756074 and parameters: {'n_estimators': 132, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 2, 'max_features': 0.5, 'max_samples': 0.7}. Best is trial 34 with value: 0.7538975469108851.
# [I 2023-05-10 11:48:16,645] Trial 27 finished with value: 0.7535300888462388 and parameters: {'n_estimators': 110, 'max_depth': 9, 'min_samples_split': 50, 'min_samples_leaf': 2, 'max_features': 0.4, 'max_samples': 0.7}. Best is trial 34 with value: 0.7538975469108851.
# [I 2023-05-10 11:48:17,018] Trial 1 finished with value: 0.7534367569731665 and parameters: {'n_estimators': 156, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 0.2, 'max_samples': 0.4}. Best is trial 34 with value: 0.7538975469108851.
# [I 2023-05-10 11:48:17,470] Trial 22 finished with value: 0.7522421746722396 and parameters: {'n_estimators': 119, 'max_depth': 5, 'min_samples_split': 35, 'min_samples_leaf': 8, 'max_features': 0.5, 'max_samples': 0.4}. Best is trial 34 with value: 0.7538975469108851.
# [I 2023-05-10 11:48:18,824] Trial 37 finished with value: 0.7545945504067351 and parameters: {'n_estimators': 150, 'max_depth': 10, 'min_samples_split': 20, 'min_samples_leaf': 3, 'max_features': 0.30000000000000004, 'max_samples': 0.6000000000000001}. Best is trial 37 with value: 0.7545945504067351.
# [I 2023-05-10 11:48:37,685] Trial 10 finished with value: 0.7516920397288098 and parameters: {'n_estimators': 161, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': 0.6, 'max_samples': 0.7}. Best is trial 37 with value: 0.7545945504067351.
# [I 2023-05-10 11:48:38,272] Trial 31 finished with value: 0.7531212156691608 and parameters: {'n_estimators': 182, 'max_depth': 6, 'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': 0.5, 'max_samples': 0.7}. Best is trial 37 with value: 0.7545945504067351.
# [I 2023-05-10 11:48:38,594] Trial 15 finished with value: 0.7522315128061343 and parameters: {'n_estimators': 209, 'max_depth': 6, 'min_samples_split': 25, 'min_samples_leaf': 10, 'max_features': 0.6, 'max_samples': 0.7}. Best is trial 37 with value: 0.7545945504067351.
# [I 2023-05-10 11:48:39,658] Trial 32 finished with value: 0.7512385877894171 and parameters: {'n_estimators': 192, 'max_depth': 10, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': 0.5, 'max_samples': 0.6000000000000001}. Best is trial 37 with value: 0.7545945504067351.
# [I 2023-05-10 11:48:41,314] Trial 4 finished with value: 0.7542699658481922 and parameters: {'n_estimators': 214, 'max_depth': 8, 'min_samples_split': 35, 'min_samples_leaf': 7, 'max_features': 0.2, 'max_samples': 0.7}. Best is trial 37 with value: 0.7545945504067351.
# [I 2023-05-10 11:48:41,850] Trial 0 finished with value: 0.7522750310118732 and parameters: {'n_estimators': 216, 'max_depth': 7, 'min_samples_split': 25, 'min_samples_leaf': 5, 'max_features': 0.5, 'max_samples': 0.5}. Best is trial 37 with value: 0.7545945504067351.
# [I 2023-05-10 11:48:42,831] Trial 13 finished with value: 0.754727564406007 and parameters: {'n_estimators': 230, 'max_depth': 6, 'min_samples_split': 15, 'min_samples_leaf': 9, 'max_features': 0.2, 'max_samples': 0.6000000000000001}. Best is trial 13 with value: 0.754727564406007.
# [I 2023-05-10 11:48:43,447] Trial 36 finished with value: 0.7527389506138604 and parameters: {'n_estimators': 218, 'max_depth': 9, 'min_samples_split': 25, 'min_samples_leaf': 6, 'max_features': 0.4, 'max_samples': 0.6000000000000001}. Best is trial 13 with value: 0.754727564406007.
# [I 2023-05-10 11:49:03,356] Trial 41 finished with value: 0.7529969413880733 and parameters: {'n_estimators': 103, 'max_depth': 6, 'min_samples_split': 30, 'min_samples_leaf': 4, 'max_features': 0.30000000000000004, 'max_samples': 0.4}. Best is trial 13 with value: 0.754727564406007.
# [I 2023-05-10 11:49:04,113] Trial 24 finished with value: 0.7539616952248531 and parameters: {'n_estimators': 285, 'max_depth': 9, 'min_samples_split': 45, 'min_samples_leaf': 8, 'max_features': 0.30000000000000004, 'max_samples': 0.6000000000000001}. Best is trial 13 with value: 0.754727564406007.
# [I 2023-05-10 11:49:04,578] Trial 43 finished with value: 0.7532614222942269 and parameters: {'n_estimators': 149, 'max_depth': 10, 'min_samples_split': 40, 'min_samples_leaf': 8, 'max_features': 0.6, 'max_samples': 0.5}. Best is trial 13 with value: 0.754727564406007.
# [I 2023-05-10 11:49:05,204] Trial 44 finished with value: 0.7524194328062388 and parameters: {'n_estimators': 132, 'max_depth': 7, 'min_samples_split': 35, 'min_samples_leaf': 8, 'max_features': 0.5, 'max_samples': 0.6000000000000001}. Best is trial 13 with value: 0.754727564406007.
# [I 2023-05-10 11:49:05,641] Trial 17 finished with value: 0.7538773703798938 and parameters: {'n_estimators': 307, 'max_depth': 7, 'min_samples_split': 20, 'min_samples_leaf': 5, 'max_features': 0.5, 'max_samples': 0.6000000000000001}. Best is trial 13 with value: 0.754727564406007.
# [I 2023-05-10 11:49:06,122] Trial 8 finished with value: 0.7519427615029635 and parameters: {'n_estimators': 301, 'max_depth': 5, 'min_samples_split': 45, 'min_samples_leaf': 5, 'max_features': 0.4, 'max_samples': 0.6000000000000001}. Best is trial 13 with value: 0.754727564406007.
# [I 2023-05-10 11:49:06,143] Trial 6 finished with value: 0.7526400394046392 and parameters: {'n_estimators': 268, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 0.5, 'max_samples': 0.7}. Best is trial 13 with value: 0.754727564406007.
# [I 2023-05-10 11:49:06,584] Trial 46 finished with value: 0.7521643617137489 and parameters: {'n_estimators': 124, 'max_depth': 10, 'min_samples_split': 40, 'min_samples_leaf': 3, 'max_features': 0.5, 'max_samples': 0.6000000000000001}. Best is trial 13 with value: 0.754727564406007.
# [I 2023-05-10 11:49:07,075] Trial 25 finished with value: 0.7530941203579993 and parameters: {'n_estimators': 260, 'max_depth': 9, 'min_samples_split': 45, 'min_samples_leaf': 5, 'max_features': 0.6, 'max_samples': 0.6000000000000001}. Best is trial 13 with value: 0.754727564406007.
# [I 2023-05-10 11:49:07,501] Trial 16 finished with value: 0.7532851031715488 and parameters: {'n_estimators': 313, 'max_depth': 8, 'min_samples_split': 30, 'min_samples_leaf': 4, 'max_features': 0.4, 'max_samples': 0.7}. Best is trial 13 with value: 0.754727564406007.
# [I 2023-05-10 11:49:07,908] Trial 39 finished with value: 0.7531200131946347 and parameters: {'n_estimators': 286, 'max_depth': 8, 'min_samples_split': 25, 'min_samples_leaf': 9, 'max_features': 0.4, 'max_samples': 0.4}. Best is trial 13 with value: 0.754727564406007.
# [I 2023-05-10 11:49:08,702] Trial 19 finished with value: 0.7522797282159215 and parameters: {'n_estimators': 317, 'max_depth': 9, 'min_samples_split': 30, 'min_samples_leaf': 1, 'max_features': 0.6, 'max_samples': 0.7}. Best is trial 13 with value: 0.754727564406007.
# [I 2023-05-10 11:49:09,018] Trial 26 finished with value: 0.7551063260486475 and parameters: {'n_estimators': 299, 'max_depth': 8, 'min_samples_split': 45, 'min_samples_leaf': 3, 'max_features': 0.2, 'max_samples': 0.6000000000000001}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:49:09,851] Trial 9 finished with value: 0.7536660752796297 and parameters: {'n_estimators': 307, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 0.5, 'max_samples': 0.5}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:49:10,152] Trial 30 finished with value: 0.7548661470975817 and parameters: {'n_estimators': 282, 'max_depth': 9, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': 0.30000000000000004, 'max_samples': 0.5}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:49:28,580] Trial 42 finished with value: 0.7525144562105629 and parameters: {'n_estimators': 179, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': 0.6, 'max_samples': 0.4}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:49:29,374] Trial 38 finished with value: 0.7522019883638483 and parameters: {'n_estimators': 383, 'max_depth': 5, 'min_samples_split': 40, 'min_samples_leaf': 5, 'max_features': 0.4, 'max_samples': 0.7}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:49:30,025] Trial 29 finished with value: 0.7540788848124824 and parameters: {'n_estimators': 373, 'max_depth': 8, 'min_samples_split': 35, 'min_samples_leaf': 10, 'max_features': 0.30000000000000004, 'max_samples': 0.4}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:49:30,150] Trial 5 finished with value: 0.753406387652242 and parameters: {'n_estimators': 331, 'max_depth': 7, 'min_samples_split': 40, 'min_samples_leaf': 5, 'max_features': 0.6, 'max_samples': 0.5}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:49:30,661] Trial 48 finished with value: 0.7524980525496027 and parameters: {'n_estimators': 171, 'max_depth': 5, 'min_samples_split': 45, 'min_samples_leaf': 2, 'max_features': 0.30000000000000004, 'max_samples': 0.5}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:49:33,051] Trial 3 finished with value: 0.7543108568912462 and parameters: {'n_estimators': 394, 'max_depth': 8, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 0.30000000000000004, 'max_samples': 0.6000000000000001}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:49:33,125] Trial 51 finished with value: 0.75431163239815 and parameters: {'n_estimators': 232, 'max_depth': 7, 'min_samples_split': 25, 'min_samples_leaf': 5, 'max_features': 0.2, 'max_samples': 0.6000000000000001}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:49:34,596] Trial 52 finished with value: 0.7543011526912031 and parameters: {'n_estimators': 200, 'max_depth': 10, 'min_samples_split': 25, 'min_samples_leaf': 5, 'max_features': 0.30000000000000004, 'max_samples': 0.6000000000000001}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:49:52,720] Trial 53 finished with value: 0.7542419814023995 and parameters: {'n_estimators': 210, 'max_depth': 10, 'min_samples_split': 25, 'min_samples_leaf': 5, 'max_features': 0.30000000000000004, 'max_samples': 0.6000000000000001}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:49:53,678] Trial 54 finished with value: 0.7545638163940255 and parameters: {'n_estimators': 240, 'max_depth': 10, 'min_samples_split': 25, 'min_samples_leaf': 4, 'max_features': 0.30000000000000004, 'max_samples': 0.6000000000000001}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:49:54,226] Trial 14 finished with value: 0.7543434787861607 and parameters: {'n_estimators': 440, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': 0.2, 'max_samples': 0.6000000000000001}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:49:54,727] Trial 40 finished with value: 0.7527967656525696 and parameters: {'n_estimators': 311, 'max_depth': 9, 'min_samples_split': 45, 'min_samples_leaf': 5, 'max_features': 0.5, 'max_samples': 0.4}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:49:55,162] Trial 45 finished with value: 0.7528495097388392 and parameters: {'n_estimators': 302, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 0.30000000000000004, 'max_samples': 0.7}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:49:55,725] Trial 49 finished with value: 0.753591344368201 and parameters: {'n_estimators': 290, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': 0.2, 'max_samples': 0.5}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:49:56,890] Trial 50 finished with value: 0.7549729689253842 and parameters: {'n_estimators': 256, 'max_depth': 7, 'min_samples_split': 25, 'min_samples_leaf': 5, 'max_features': 0.2, 'max_samples': 0.7}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:49:58,173] Trial 20 finished with value: 0.753349064844739 and parameters: {'n_estimators': 437, 'max_depth': 6, 'min_samples_split': 40, 'min_samples_leaf': 6, 'max_features': 0.5, 'max_samples': 0.7}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:50:17,057] Trial 28 finished with value: 0.7517008008280539 and parameters: {'n_estimators': 486, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': 0.6, 'max_samples': 0.6000000000000001}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:50:18,082] Trial 35 finished with value: 0.7529475309731257 and parameters: {'n_estimators': 497, 'max_depth': 6, 'min_samples_split': 35, 'min_samples_leaf': 3, 'max_features': 0.6, 'max_samples': 0.6000000000000001}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:50:18,746] Trial 55 finished with value: 0.7536567178448939 and parameters: {'n_estimators': 296, 'max_depth': 10, 'min_samples_split': 25, 'min_samples_leaf': 6, 'max_features': 0.30000000000000004, 'max_samples': 0.6000000000000001}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:50:19,754] Trial 56 finished with value: 0.7540059570993239 and parameters: {'n_estimators': 277, 'max_depth': 8, 'min_samples_split': 25, 'min_samples_leaf': 4, 'max_features': 0.30000000000000004, 'max_samples': 0.5}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:50:20,882] Trial 57 finished with value: 0.7545625386656389 and parameters: {'n_estimators': 254, 'max_depth': 8, 'min_samples_split': 25, 'min_samples_leaf': 4, 'max_features': 0.30000000000000004, 'max_samples': 0.5}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:50:21,870] Trial 58 finished with value: 0.7544050787392532 and parameters: {'n_estimators': 283, 'max_depth': 8, 'min_samples_split': 50, 'min_samples_leaf': 3, 'max_features': 0.30000000000000004, 'max_samples': 0.5}. Best is trial 26 with value: 0.7551063260486475.
# [I 2023-05-10 11:50:22,392] Trial 68 finished with value: 0.7551871733436262 and parameters: {'n_estimators': 239, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 0.2, 'max_samples': 0.5}. Best is trial 68 with value: 0.7551871733436262.
# [I 2023-05-10 11:50:23,261] Trial 59 finished with value: 0.7554376696362997 and parameters: {'n_estimators': 272, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 0.30000000000000004, 'max_samples': 0.5}. Best is trial 59 with value: 0.7554376696362997.
# [I 2023-05-10 11:50:24,293] Trial 60 finished with value: 0.7536358517047054 and parameters: {'n_estimators': 273, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 0.30000000000000004, 'max_samples': 0.5}. Best is trial 59 with value: 0.7554376696362997.
# [I 2023-05-10 11:50:42,815] Trial 61 finished with value: 0.7550300455239173 and parameters: {'n_estimators': 274, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 0.2, 'max_samples': 0.5}. Best is trial 59 with value: 0.7554376696362997.
# [I 2023-05-10 11:50:42,892] Trial 62 finished with value: 0.7550528583675664 and parameters: {'n_estimators': 256, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 0.2, 'max_samples': 0.5}. Best is trial 59 with value: 0.7554376696362997.
# [I 2023-05-10 11:50
 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_features': 0.2, 'max_samples': 0.5}. Best is trial 59 with value: 0.7554376696362997.
# [I 2023-05-10 11:51:13,894] Trial 81 finished with value: 0.7549844794048111 and parameters: {'n_estimators': 450, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_features': 0.2, 'max_samples': 0.5}. Best is trial 59 with value: 0.7554376696362997.
# [I 2023-05-10 11:51:14,072] Trial 95 finished with value: 0.7548069253905592 and parameters: {'n_estimators': 255, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_features': 0.2, 'max_samples': 0.5}. Best is trial 59 with value: 0.7554376696362997.
# [I 2023-05-10 11:51:14,082] Trial 98 finished with value: 0.7551451200672542 and parameters: {'n_estimators': 246, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 0.2, 'max_samples': 0.5}. Best is trial 59 with value: 0.7554376696362997.
# [I 2023-05-10 11:51:14,085] Trial 99 finished with value: 0.7541218228352331 and parameters: {'n_estimators': 247, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': 0.2, 'max_samples': 0.5}. Best is trial 59 with value: 0.7554376696362997.

# %%
optuna_search.best_params_
# Out:
# {'n_estimators': 272,
#  'max_depth': 8,
#  'min_samples_split': 5,
#  'min_samples_leaf': 3,
#  'max_features': 0.30000000000000004,
#  'max_samples': 0.5}

# %%
def train_rf_cv(X, y, param, verbose=True):
    clf = RandomForestClassifier(**param)
    cvs = []
    for fold in range(0, 5):
        train_x = X.query(f'fold != {fold}').drop(columns='fold')
        train_y = y[train_x.index]
        valid_x = X.query(f'fold == {fold}').drop(columns='fold')
        valid_y = y[valid_x.index]
        valid_score = clf.fit(train_x, train_y).predict_proba(valid_x)[:, 1]
        cvs.append(roc_auc_score(valid_y, valid_score))
    
    if verbose:
        print("five fold auc:", *cvs, sep=", ")
        print("mean auc:", np.mean(cvs))
        
    return cvs

# %%
def train_rf(X, y, param):
    clf = RandomForestClassifier(**param)
    clf.fit(X, y)
    return clf

# %%
param = {'n_estimators':272, 'criterion':'entropy', 'max_depth':8, 'min_samples_split':5, 'min_samples_leaf':3, \
         'max_features':0.3,'n_jobs':-1, 'random_state':42, 'class_weight':'balanced', 'max_samples':0.5}
# param.update(optuna_search.best_params_)
cvs = train_rf_cv(train.drop('order_status_key', axis=1), train['order_status_key'], param)
# Out:
# five fold auc:, 0.7496287958616725, 0.7326432129514321, 0.7443634727845254, 0.7819523166891588, 0.7558940158615717
# mean auc: 0.7528963628296721

# %%
clf = train_rf(train.drop(['order_status_key', 'fold'], axis=1), train['order_status_key'], param)
pickle.dump(clf, open(config.RF, "wb"))

# %% [markdown]
# ## XGBoost

# %%
train = pd.read_csv(config.TRAIN3)
cat_features = ['gender', 'degree', 'card_num']
train[cat_features] = train[cat_features].astype('category')

# %%
def objective(trial):
    data = train.copy()
    param = {
        'booster':'gbtree', 
        'objective':'binary:logistic',
        # 'eval_metric':roc_auc_score,
        'grow_policy':'lossguide',
        'n_estimators': 88,
        'max_leaves': 28,
        'max_depth': 4,
        'eta': 0.00039413682468496394,
        'min_child_weight': 20,
        'subsample': 0.7,
        'colsample_bytree': 0.4,
        'scale_pos_weight': 6.0,
        'max_bin': 140,
        'random_state':42,
        'tree_method':'approx',
        'enable_categorical':True
        # 'early_stopping_rounds':10
    }
    
    # Add a callback for pruning.
    # pruning_callback = optuna.integration.XGBoostPruningCallback(trial, "validation-auc")
    aucs = []
    for fold in range(0, 5):
        train_fold = data.query(f"fold != {fold}").drop('fold', axis=1)
        valid_fold = data.query(f"fold == {fold}").drop('fold', axis=1)
        train_x, train_y = train_fold.drop('order_status_key', axis=1), train_fold['order_status_key']
        valid_x, valid_y = valid_fold.drop('order_status_key', axis=1), valid_fold['order_status_key'] 
        clf = XGBClassifier(**param).fit(train_x, train_y, verbose=False)
        preds = clf.predict_proba(valid_x)[:, 1]
        value = roc_auc_score(valid_y, preds)
        aucs.append(value)
    return np.mean(aucs)


if __name__ == "__main__":
    study = optuna.create_study(
        # pruner=optuna.pruners.MedianPruner(n_warmup_steps=10), 
        direction="maximize"
    )
    study.optimize(objective, n_trials=100)

    print("Number of finished trials: {}".format(len(study.trials)))

    print("Best trial:")
    trial = study.best_trial

    print("  Value: {}".format(trial.value))

    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))

# %%
param = {
        'booster':'gbtree', 
        'objective':'binary:logistic',
        'grow_policy':'lossguide',
        'n_estimators': 88,
        'max_leaves': 28,
        'max_depth': 4,
        'eta': 0.00039413682468496394,
        'min_child_weight': 20,
        'subsample': 0.8,
        'colsample_bytree': 0.4,
        'scale_pos_weight': 9,
        'max_bin': 140,
        'random_state':42,
        'tree_method':'approx',
        'enable_categorical':True}
train_x, train_y = train.drop(['order_status_key', 'fold'], axis=1), train['order_status_key']
clf = XGBClassifier(**param).fit(train_x, train_y)

# %%
clf.save_model(config.XGBOOST)

# %% [markdown]
# ## Catboost

# %%
train = pd.read_csv(config.TRAIN3)
cat_features= ['gender', 'degree', 'card_num']
train[cat_features] = train[cat_features].astype('category')

# %%
Number of finished trials: 100
value: 0.7557021810734862 and parameters: {'iterations': 220, 'learning_rate': 0.02200043117064521}

# %%
def objective(trial):
    data = train.copy()
    param_distribution = {
        'loss_function':'Logloss',
        'iterations':trial.suggest_int('iterations', 200, 250, step=5),
        'learning_rate':trial.suggest_float('learning_rate', 1e-2, 0.05, log=True),
        # 'bagging_temperature':trial.suggest_float('bagging_temperature', 1e-2, 1e2, log=True),
        'subsample':0.7,
        # 'sampling_frequency':'PerTree',
        'depth':trial.suggest_int('depth', 5, 10, step=1),
        'grow_policy':'Lossguide',
        # 'min_data_in_leaf':trial.suggest_int('min_data_in_leaf', 10, 20, step=1),
        'max_leaves':trial.suggest_int('max_leaves', 15, 20, step = 1),
        'scale_pos_weight':trial.suggest_float('scale_pos_weight', 0.5, 20, log=True),
        # 'border_count':trial.suggest_int('border_count', 100, 300, step=10),
        'random_seed':42,
        'verbose':False
    }
    
    cvs = []
    clf = CatBoostClassifier(**param_distribution)
    for fold in range(0, 5):
        train_fold = data.query(f'fold !={fold}')
        valid_fold = data.query(f'fold == {fold}')
        train_x = train_fold.drop(columns=['fold', 'order_status_key'])
        train_y = train_fold['order_status_key']
        train_data = Pool(train_x, train_y, cat_features= ['gender', 'degree', 'card_num'])
        valid_x = valid_fold.drop(columns=['fold', 'order_status_key'])
        valid_y = valid_fold['order_status_key']
        valid_data = Pool(valid_x, valid_y, cat_features= ['gender', 'degree', 'card_num'])
        valid_score = clf.fit(train_data).predict_proba(valid_data)[:, 1]
        cvs.append(roc_auc_score(valid_y, valid_score))
        
    return np.mean(cvs)


study = optuna.create_study(
        # pruner=optuna.pruners.MedianPruner(n_warmup_steps=10), 
        direction="maximize"
    )
study.optimize(objective, n_trials=100)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))

# %%
param = {'loss_function':'Logloss', 'iterations':225, 'learning_rate':0.020248583615876215, 'depth':7, 'max_leaves':17, 'scale_pos_weight': 1.0350162147070745, 
         'subsample':0.7, 'grow_policy':'Lossguide', 'verbose':False}
train_x, train_y = train.drop(['order_status_key', 'fold'], axis=1), train['order_status_key']
train_data = Pool(train_x, train_y, cat_features= ['gender', 'degree', 'card_num'])
clf = CatBoostClassifier(**param).fit(train_data)
clf.save_model(config.CATBOOST)

# %% [markdown]
# ## LightGBM

# %%
train = pd.read_csv(config.TRAIN3)

# %%
Best trial
Avg of five fold auc:0.757285
Params
num_iterations:995
learning_rate:0.00471212286205368
num_leaves:5
max_depth:11
min_data_in_leaft:7
max_int:405
min_data_in_bin:19
bagging_fraction:0.6000000000000001
neg_bagging_fraction:0.3693772602188242
feature_fraction:0.3

# %%
def objective(trial):
    data = train.copy()
    
    param_distribution = {
        'objective': 'binary',
        'num_iterations': trial.suggest_int('num_iterations', 800, 1200, log=True),
        'learning_rate': trial.suggest_float('learning_rate', 1e-5, 0.05, log=True),
        'num_leaves': trial.suggest_int('num_leaves', 3, 10, step=1),
        'max_depth': trial.suggest_int('max_depth', 8, 15, step=1),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaft', 5, 8, step=1),
        'max_bin': trial.suggest_int('max_int', 370, 430, step=5),
        'min_data_in_bin': trial.suggest_int('min_data_in_bin', 17, 22, step=1),
        'bagging_fraction':trial.suggest_float('bagging_fraction', 0.4, 1, step=0.1),
        'neg_bagging_fraction':trial.suggest_float('neg_bagging_fraction', 0.1, 1, log=True),
        # 'cat_smooth': trial.suggest_float('cat_smooth', 1, 1e3, log=True),
        'feature_fraction':0.3,
        'verbosity':0,
        'force_col_wise':True,
        'linear_tree':True,
        'seed':42
    }
    
    aucs = []
    for fold in range(0, 5):
        train_fold = data.query(f'fold != {fold}')
        train_x, train_y = train_fold.drop(columns=['fold', 'order_status_key'], axis=1), train_fold['order_status_key']
        dtrain = lgbm.Dataset(train_x, train_y)
        valid_fold = data.query(f'fold == {fold}')
        valid_x, valid_y = valid_fold.drop(columns=['fold', 'order_status_key'], axis=1), valid_fold['order_status_key']
        dvalid = lgbm.Dataset(valid_x, valid_y)
        clf = lgbm.train(param_distribution, dtrain, categorical_feature=['gender', 'card_num', 'degree'])
        valid_score = clf.predict(valid_x)
        aucs.append(roc_auc_score(valid_y, valid_score))
    
    return np.mean(aucs)


study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=1000)

print("Best trial")
trial = study.best_trial

print(f"Avg of five fold auc:{trial.value:.6f}")

print("Params")
for key, value in trial.params.items():
    print(f"{key}:{value}")
# Out:
# [I 2023-05-10 12:53:05,950] A new study created in memory with name: no-name-b9002735-bed3-4dd5-acde-4ae024b1b14e
# [I 2023-05-10 12:53:09,614] Trial 0 finished with value: 0.7519011817843829 and parameters: {'num_iterations': 873, 'learning_rate': 2.1057936655038092e-05, 'num_leaves': 8, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 375, 'min_data_in_bin': 18, 'bagging_fraction': 0.8, 'neg_bagging_fraction': 0.44267734142050535}. Best is trial 0 with value: 0.7519011817843829.
# [I 2023-05-10 12:53:12,997] Trial 1 finished with value: 0.7542895972088474 and parameters: {'num_iterations': 1109, 'learning_rate': 0.010319594606706875, 'num_leaves': 4, 'max_depth': 12, 'min_data_in_leaft': 8, 'max_int': 380, 'min_data_in_bin': 19, 'bagging_fraction': 0.8, 'neg_bagging_fraction': 0.9743869850194536}. Best is trial 1 with value: 0.7542895972088474.
# [I 2023-05-10 12:53:17,997] Trial 2 finished with value: 0.7503311222143234 and parameters: {'num_iterations': 1197, 'learning_rate': 4.440116814073193e-05, 'num_leaves': 5, 'max_depth': 8, 'min_data_in_leaft': 8, 'max_int': 375, 'min_data_in_bin': 18, 'bagging_fraction': 0.7000000000000001, 'neg_bagging_fraction': 0.26218136401173026}. Best is trial 1 with value: 0.7542895972088474.
# [I 2023-05-10 12:53:22,233] Trial 3 finished with value: 0.7515455147672162 and parameters: {'num_iterations': 1027, 'learning_rate': 0.00027161361702674066, 'num_leaves': 6, 'max_depth': 13, 'min_data_in_leaft': 5, 'max_int': 375, 'min_data_in_bin': 20, 'bagging_fraction': 0.9, 'neg_bagging_fraction': 0.5476426995241362}. Best is trial 1 with value: 0.7542895972088474.
# [I 2023-05-10 12:53:27,270] Trial 4 finished with value: 0.752778739365257 and parameters: {'num_iterations': 800, 'learning_rate': 0.00032149309987195837, 'num_leaves': 9, 'max_depth': 12, 'min_data_in_leaft': 6, 'max_int': 415, 'min_data_in_bin': 22, 'bagging_fraction': 1.0, 'neg_bagging_fraction': 0.6776265173007514}. Best is trial 1 with value: 0.7542895972088474.
# [I 2023-05-10 12:53:31,455] Trial 5 finished with value: 0.7511721747637392 and parameters: {'num_iterations': 1053, 'learning_rate': 0.016065517574076704, 'num_leaves': 6, 'max_depth': 8, 'min_data_in_leaft': 8, 'max_int': 410, 'min_data_in_bin': 21, 'bagging_fraction': 0.8, 'neg_bagging_fraction': 0.6989668358224979}. Best is trial 1 with value: 0.7542895972088474.
# [I 2023-05-10 12:53:35,936] Trial 6 finished with value: 0.7554732130802786 and parameters: {'num_iterations': 877, 'learning_rate': 0.0025499698538356207, 'num_leaves': 10, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 425, 'min_data_in_bin': 19, 'bagging_fraction': 0.5, 'neg_bagging_fraction': 0.4097146700676824}. Best is trial 6 with value: 0.7554732130802786.
# [I 2023-05-10 12:53:41,450] Trial 7 finished with value: 0.7537679550015527 and parameters: {'num_iterations': 1087, 'learning_rate': 0.0004798378915557657, 'num_leaves': 10, 'max_depth': 13, 'min_data_in_leaft': 8, 'max_int': 400, 'min_data_in_bin': 19, 'bagging_fraction': 0.9, 'neg_bagging_fraction': 0.30326597632722435}. Best is trial 6 with value: 0.7554732130802786.
# [I 2023-05-10 12:53:46,048] Trial 8 finished with value: 0.7545384804919772 and parameters: {'num_iterations': 870, 'learning_rate': 0.0013278080350700731, 'num_leaves': 10, 'max_depth': 11, 'min_data_in_leaft': 7, 'max_int': 395, 'min_data_in_bin': 17, 'bagging_fraction': 0.5, 'neg_bagging_fraction': 0.10804396514250247}. Best is trial 6 with value: 0.7554732130802786.
# [I 2023-05-10 12:53:49,997] Trial 9 finished with value: 0.7517935237610797 and parameters: {'num_iterations': 924, 'learning_rate': 0.00011152484436708108, 'num_leaves': 7, 'max_depth': 10, 'min_data_in_leaft': 7, 'max_int': 385, 'min_data_in_bin': 21, 'bagging_fraction': 0.9, 'neg_bagging_fraction': 0.2063231192771826}. Best is trial 6 with value: 0.7554732130802786.
# [I 2023-05-10 12:53:52,338] Trial 10 finished with value: 0.7553686451336055 and parameters: {'num_iterations': 969, 'learning_rate': 0.0033472110958083496, 'num_leaves': 3, 'max_depth': 15, 'min_data_in_leaft': 5, 'max_int': 430, 'min_data_in_bin': 17, 'bagging_fraction': 0.4, 'neg_bagging_fraction': 0.41160421401633174}. Best is trial 6 with value: 0.7554732130802786.
# [I 2023-05-10 12:53:55,193] Trial 11 finished with value: 0.7558238141868279 and parameters: {'num_iterations': 951, 'learning_rate': 0.0047802106157917605, 'num_leaves': 3, 'max_depth': 15, 'min_data_in_leaft': 5, 'max_int': 430, 'min_data_in_bin': 17, 'bagging_fraction': 0.4, 'neg_bagging_fraction': 0.4059082172844469}. Best is trial 11 with value: 0.7558238141868279.
# [I 2023-05-10 12:53:57,815] Trial 12 finished with value: 0.748211671182832 and parameters: {'num_iterations': 942, 'learning_rate': 0.048191776587892365, 'num_leaves': 3, 'max_depth': 14, 'min_data_in_leaft': 5, 'max_int': 430, 'min_data_in_bin': 18, 'bagging_fraction': 0.5, 'neg_bagging_fraction': 0.3746644812274747}. Best is trial 11 with value: 0.7558238141868279.
# [I 2023-05-10 12:54:01,972] Trial 13 finished with value: 0.7556133615376586 and parameters: {'num_iterations': 896, 'learning_rate': 0.0019232096935257086, 'num_leaves': 8, 'max_depth': 10, 'min_data_in_leaft': 6, 'max_int': 420, 'min_data_in_bin': 20, 'bagging_fraction': 0.4, 'neg_bagging_fraction': 0.23666201363815914}. Best is trial 11 with value: 0.7558238141868279.
# [I 2023-05-10 12:54:06,514] Trial 14 finished with value: 0.7546359711211912 and parameters: {'num_iterations': 1001, 'learning_rate': 0.00114658937424474, 'num_leaves': 8, 'max_depth': 9, 'min_data_in_leaft': 5, 'max_int': 415, 'min_data_in_bin': 20, 'bagging_fraction': 0.4, 'neg_bagging_fraction': 0.20719838425266193}. Best is trial 11 with value: 0.7558238141868279.
# [I 2023-05-10 12:54:10,247] Trial 15 finished with value: 0.7569884397559234 and parameters: {'num_iterations': 941, 'learning_rate': 0.0047851570286327975, 'num_leaves': 5, 'max_depth': 15, 'min_data_in_leaft': 6, 'max_int': 420, 'min_data_in_bin': 21, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.25126400665924314}. Best is trial 15 with value: 0.7569884397559234.
# [I 2023-05-10 12:54:13,327] Trial 16 finished with value: 0.7566396108497766 and parameters: {'num_iterations': 974, 'learning_rate': 0.006195058086477415, 'num_leaves': 4, 'max_depth': 15, 'min_data_in_leaft': 7, 'max_int': 410, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.17196247990028823}. Best is trial 15 with value: 0.7569884397559234.
# [I 2023-05-10 12:54:16,573] Trial 17 finished with value: 0.7555179080845988 and parameters: {'num_iterations': 995, 'learning_rate': 0.009483428485880943, 'num_leaves': 5, 'max_depth': 14, 'min_data_in_leaft': 7, 'max_int': 410, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.1574150392601798}. Best is trial 15 with value: 0.7569884397559234.
# [I 2023-05-10 12:54:20,223] Trial 18 finished with value: 0.7521139442415578 and parameters: {'num_iterations': 981, 'learning_rate': 0.00074409179625236, 'num_leaves': 5, 'max_depth': 14, 'min_data_in_leaft': 7, 'max_int': 405, 'min_data_in_bin': 21, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.16017032676004841}. Best is trial 15 with value: 0.7569884397559234.
# [I 2023-05-10 12:54:23,652] Trial 19 finished with value: 0.7570011586853693 and parameters: {'num_iterations': 908, 'learning_rate': 0.005193919213412017, 'num_leaves': 4, 'max_depth': 15, 'min_data_in_leaft': 7, 'max_int': 395, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.309992143258915}. Best is trial 19 with value: 0.7570011586853693.
# [I 2023-05-10 12:54:26,827] Trial 20 finished with value: 0.7505208231913351 and parameters: {'num_iterations': 925, 'learning_rate': 0.027112206440724977, 'num_leaves': 4, 'max_depth': 13, 'min_data_in_leaft': 6, 'max_int': 390, 'min_data_in_bin': 21, 'bagging_fraction': 0.7000000000000001, 'neg_bagging_fraction': 0.2799439409497811}. Best is trial 19 with value: 0.7570011586853693.
# [I 2023-05-10 12:54:29,808] Trial 21 finished with value: 0.7570023887965489 and parameters: {'num_iterations': 915, 'learning_rate': 0.004936343442556598, 'num_leaves': 4, 'max_depth': 15, 'min_data_in_leaft': 7, 'max_int': 400, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.3222702437196369}. Best is trial 21 with value: 0.7570023887965489.
# [I 2023-05-10 12:54:32,820] Trial 22 finished with value: 0.7563922264816281 and parameters: {'num_iterations': 905, 'learning_rate': 0.004046058128988444, 'num_leaves': 4, 'max_depth': 15, 'min_data_in_leaft': 7, 'max_int': 395, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0
. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:55:25,683] Trial 38 finished with value: 0.7566319720227435 and parameters: {'num_iterations': 925, 'learning_rate': 0.005334561440625512, 'num_leaves': 5, 'max_depth': 15, 'min_data_in_leaft': 8, 'max_int': 415, 'min_data_in_bin': 20, 'bagging_fraction': 0.8, 'neg_bagging_fraction': 0.2533255419379731}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:55:29,385] Trial 39 finished with value: 0.7492069449416241 and parameters: {'num_iterations': 962, 'learning_rate': 0.018353975637974612, 'num_leaves': 7, 'max_depth': 12, 'min_data_in_leaft': 7, 'max_int': 400, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.2905506453318752}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:55:34,007] Trial 40 finished with value: 0.7527456979720859 and parameters: {'num_iterations': 1197, 'learning_rate': 0.0005514958662111673, 'num_leaves': 6, 'max_depth': 14, 'min_data_in_leaft': 6, 'max_int': 420, 'min_data_in_bin': 19, 'bagging_fraction': 0.7000000000000001, 'neg_bagging_fraction': 0.3828682390010523}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:55:36,315] Trial 41 finished with value: 0.7562191482980957 and parameters: {'num_iterations': 888, 'learning_rate': 0.012176671978032762, 'num_leaves': 3, 'max_depth': 13, 'min_data_in_leaft': 7, 'max_int': 395, 'min_data_in_bin': 22, 'bagging_fraction': 0.7000000000000001, 'neg_bagging_fraction': 0.33076517435958647}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:55:38,894] Trial 42 finished with value: 0.7566905489367637 and parameters: {'num_iterations': 887, 'learning_rate': 0.008611969325912197, 'num_leaves': 3, 'max_depth': 11, 'min_data_in_leaft': 7, 'max_int': 395, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.3594866269581258}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:55:41,638] Trial 43 finished with value: 0.7560722883354462 and parameters: {'num_iterations': 908, 'learning_rate': 0.003171356317437775, 'num_leaves': 4, 'max_depth': 13, 'min_data_in_leaft': 7, 'max_int': 390, 'min_data_in_bin': 22, 'bagging_fraction': 0.7000000000000001, 'neg_bagging_fraction': 0.4267897912795525}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:55:44,172] Trial 44 finished with value: 0.75556819288218 and parameters: {'num_iterations': 865, 'learning_rate': 0.00451181256846963, 'num_leaves': 3, 'max_depth': 12, 'min_data_in_leaft': 7, 'max_int': 385, 'min_data_in_bin': 21, 'bagging_fraction': 1.0, 'neg_bagging_fraction': 0.2837608341496842}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:55:47,136] Trial 45 finished with value: 0.7551232687177172 and parameters: {'num_iterations': 918, 'learning_rate': 0.0024578225631967823, 'num_leaves': 4, 'max_depth': 10, 'min_data_in_leaft': 8, 'max_int': 375, 'min_data_in_bin': 21, 'bagging_fraction': 0.8, 'neg_bagging_fraction': 0.38213972583729733}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:55:49,642] Trial 46 finished with value: 0.75666159020557 and parameters: {'num_iterations': 941, 'learning_rate': 0.009047825963338276, 'num_leaves': 3, 'max_depth': 15, 'min_data_in_leaft': 6, 'max_int': 400, 'min_data_in_bin': 18, 'bagging_fraction': 0.5, 'neg_bagging_fraction': 0.33295681477265354}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:55:52,890] Trial 47 finished with value: 0.7538019064435791 and parameters: {'num_iterations': 892, 'learning_rate': 0.0017699954594242965, 'num_leaves': 4, 'max_depth': 14, 'min_data_in_leaft': 5, 'max_int': 405, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.22807021777006997}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:55:55,954] Trial 48 finished with value: 0.7566429027860175 and parameters: {'num_iterations': 851, 'learning_rate': 0.005396342907207178, 'num_leaves': 5, 'max_depth': 13, 'min_data_in_leaft': 7, 'max_int': 390, 'min_data_in_bin': 20, 'bagging_fraction': 0.7000000000000001, 'neg_bagging_fraction': 0.272619570353846}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:56:00,311] Trial 49 finished with value: 0.7519593325710845 and parameters: {'num_iterations': 875, 'learning_rate': 0.015486421900947457, 'num_leaves': 9, 'max_depth': 8, 'min_data_in_leaft': 6, 'max_int': 395, 'min_data_in_bin': 22, 'bagging_fraction': 0.5, 'neg_bagging_fraction': 0.45955448951233446}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:56:03,239] Trial 50 finished with value: 0.7552908953846228 and parameters: {'num_iterations': 954, 'learning_rate': 0.0034235269739261135, 'num_leaves': 3, 'max_depth': 15, 'min_data_in_leaft': 6, 'max_int': 425, 'min_data_in_bin': 21, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.4019922932212962}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:56:05,730] Trial 51 finished with value: 0.7564872839649336 and parameters: {'num_iterations': 889, 'learning_rate': 0.007398385911889136, 'num_leaves': 3, 'max_depth': 11, 'min_data_in_leaft': 7, 'max_int': 395, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.35964279419667594}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:56:08,027] Trial 52 finished with value: 0.7564267590403134 and parameters: {'num_iterations': 914, 'learning_rate': 0.010450903448593965, 'num_leaves': 3, 'max_depth': 10, 'min_data_in_leaft': 7, 'max_int': 400, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.3118739789140428}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:56:11,280] Trial 53 finished with value: 0.7564131728241317 and parameters: {'num_iterations': 935, 'learning_rate': 0.007781996131740276, 'num_leaves': 4, 'max_depth': 11, 'min_data_in_leaft': 7, 'max_int': 395, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.359558019273741}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:56:13,642] Trial 54 finished with value: 0.7556667346378955 and parameters: {'num_iterations': 881, 'learning_rate': 0.004787650858712402, 'num_leaves': 3, 'max_depth': 9, 'min_data_in_leaft': 7, 'max_int': 405, 'min_data_in_bin': 22, 'bagging_fraction': 0.5, 'neg_bagging_fraction': 0.31123205386508734}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:56:16,387] Trial 55 finished with value: 0.7489257630003845 and parameters: {'num_iterations': 905, 'learning_rate': 0.027084715667885922, 'num_leaves': 4, 'max_depth': 12, 'min_data_in_leaft': 7, 'max_int': 390, 'min_data_in_bin': 21, 'bagging_fraction': 0.7000000000000001, 'neg_bagging_fraction': 0.41316175507452035}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:56:18,939] Trial 56 finished with value: 0.756633017827322 and parameters: {'num_iterations': 892, 'learning_rate': 0.009254559833582929, 'num_leaves': 3, 'max_depth': 11, 'min_data_in_leaft': 7, 'max_int': 385, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.27038425710172}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:56:22,381] Trial 57 finished with value: 0.7559436879844234 and parameters: {'num_iterations': 925, 'learning_rate': 0.002976437341452554, 'num_leaves': 5, 'max_depth': 15, 'min_data_in_leaft': 7, 'max_int': 410, 'min_data_in_bin': 21, 'bagging_fraction': 0.8, 'neg_bagging_fraction': 0.3394618915191496}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:56:25,703] Trial 58 finished with value: 0.7545497433619278 and parameters: {'num_iterations': 833, 'learning_rate': 0.015377116009370346, 'num_leaves': 4, 'max_depth': 14, 'min_data_in_leaft': 8, 'max_int': 400, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.23604437955486648}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:56:28,804] Trial 59 finished with value: 0.7569056009412896 and parameters: {'num_iterations': 900, 'learning_rate': 0.005812168556875571, 'num_leaves': 5, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 380, 'min_data_in_bin': 22, 'bagging_fraction': 0.7000000000000001, 'neg_bagging_fraction': 0.20305154464208744}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:56:32,586] Trial 60 finished with value: 0.7560948327487621 and parameters: {'num_iterations': 903, 'learning_rate': 0.005848274276519635, 'num_leaves': 6, 'max_depth': 10, 'min_data_in_leaft': 5, 'max_int': 375, 'min_data_in_bin': 20, 'bagging_fraction': 0.7000000000000001, 'neg_bagging_fraction': 0.20722502876682367}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:56:35,462] Trial 61 finished with value: 0.7567842064741848 and parameters: {'num_iterations': 920, 'learning_rate': 0.004222952435636219, 'num_leaves': 5, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 380, 'min_data_in_bin': 22, 'bagging_fraction': 0.8, 'neg_bagging_fraction': 0.19034200956429323}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:56:38,766] Trial 62 finished with value: 0.7568862095340105 and parameters: {'num_iterations': 934, 'learning_rate': 0.00415102196691183, 'num_leaves': 5, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 380, 'min_data_in_bin': 22, 'bagging_fraction': 0.9, 'neg_bagging_fraction': 0.1950043139291601}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:56:42,201] Trial 63 finished with value: 0.7566153370915447 and parameters: {'num_iterations': 934, 'learning_rate': 0.0038795591913841584, 'num_leaves': 5, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 380, 'min_data_in_bin': 22, 'bagging_fraction': 0.9, 'neg_bagging_fraction': 0.18829654238506421}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:56:45,917] Trial 64 finished with value: 0.7559662710517073 and parameters: {'num_iterations': 947, 'learning_rate': 0.002361500395023717, 'num_leaves': 6, 'max_depth': 10, 'min_data_in_leaft': 6, 'max_int': 375, 'min_data_in_bin': 22, 'bagging_fraction': 0.9, 'neg_bagging_fraction': 0.18693467956213775}. Best is trial 26 with value: 0.7570841189705646.
# [I 2023-05-10 12:56:49,600] Trial 65 finished with value: 0.7572040534567571 and parameters: {'num_iterations': 977, 'learning_rate': 0.004521835867024093, 'num_leaves': 5, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 385, 'min_data_in_bin': 21, 'bagging_fraction': 0.9, 'neg_bagging_fraction': 0.1498849194092809}. Best is trial 65 with value: 0.7572040534567571.
# [I 2023-05-10 12:56:53,059] Trial 66 finished with value: 0.7548298389772794 and parameters: {'num_iterations': 981, 'learning_rate': 0.0018949641718410287, 'num_leaves': 5, 'max_depth': 12, 'min_data_in_leaft': 6, 'max_int': 385, 'min_data_in_bin': 21, 'bagging_fraction': 1.0, 'neg_bagging_fraction': 0.14337748123793198}. Best is trial 65 with value: 0.7572040534567571.
# [I 2023-05-10 12:56:56,313] Trial 67 finished with value: 0.756743985433243 and parameters: {'num_iterations': 981, 'learning_rate': 0.005992560488093678, 'num_leaves': 5, 'max_depth': 9, 'min_data_in_leaft': 6, 'max_int': 380, 'min_data_in_bin': 21, 'bagging_fraction': 0.9, 'neg_bagging_fraction': 0.24645933413899834}. Best is trial 65 with value: 0.7572040534567571.
# [I 2023-05-10 12:57:00,235] Trial 68 finished with value: 0.755951653316109 and parameters: {'num_iterations': 960, 'learning_rate': 0.00281485065480542, 'num_leaves': 6, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 385, 'min_data_in_bin': 21, 'bagging_fraction': 1.0, 'neg_bagging_fraction': 0.2153142279191432}. Best is trial 65 with value: 0.7572040534567571.
# [I 2023-05-10 12:57:03,970] Trial 69 finished with value: 0.7539427725202781 and parameters: {'num_iterations': 941, 'learning_rate': 0.0014397989594420457, 'num_leaves': 5, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 380, 'min_data_in_bin': 19, 'bagging_fraction': 0.9, 'neg_bagging_fraction': 0.2659298796743093}. Best is trial 65 with value: 0.7572040534567571.
# [I 2023-05-10 12:57:07,346] Trial 70 finished with value: 0.7532007545179858 and parameters: {'num_iterations': 971, 'learning_rate': 0.0010667895683872462, 'num_leaves': 5, 'max_depth': 15, 'min_data_in_leaft': 5, 'max_int': 375, 'min_data_in_bin': 20, 'bagging_fraction': 0.9, 'neg_bagging_fraction': 0.24443656542661846}. Best is trial 65 with value: 0.7572040534567571.
# [I 2023-05-10 12:57:10,381] Trial 71 finished with value: 0.7566776164768234 and parameters: {'num_iterations': 911, 'learning_rate': 0.004066406493753275, 'num_leaves': 5, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 380, 'min_data_in_bin': 22, 'bagging_fraction': 0.8, 'neg_bagging_fraction': 0
. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 13:59:59,606] Trial 979 finished with value: 0.7570494400123096 and parameters: {'num_iterations': 907, 'learning_rate': 0.004506187353138059, 'num_leaves': 6, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 370, 'min_data_in_bin': 22, 'bagging_fraction': 0.7000000000000001, 'neg_bagging_fraction': 0.9212349195894599}. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 14:00:05,165] Trial 980 finished with value: 0.7563405891686352 and parameters: {'num_iterations': 970, 'learning_rate': 0.006372663268399846, 'num_leaves': 6, 'max_depth': 12, 'min_data_in_leaft': 7, 'max_int': 380, 'min_data_in_bin': 22, 'bagging_fraction': 0.9, 'neg_bagging_fraction': 0.2753436874577581}. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 14:00:09,343] Trial 981 finished with value: 0.7572072640702777 and parameters: {'num_iterations': 962, 'learning_rate': 0.005066260047733363, 'num_leaves': 6, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 400, 'min_data_in_bin': 22, 'bagging_fraction': 0.5, 'neg_bagging_fraction': 0.7836714322526087}. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 14:00:13,538] Trial 982 finished with value: 0.7567822027234429 and parameters: {'num_iterations': 900, 'learning_rate': 0.003949491946539562, 'num_leaves': 6, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 395, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.9949661094709816}. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 14:00:18,468] Trial 983 finished with value: 0.756416228261578 and parameters: {'num_iterations': 1144, 'learning_rate': 0.00319385635467759, 'num_leaves': 6, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 380, 'min_data_in_bin': 22, 'bagging_fraction': 0.9, 'neg_bagging_fraction': 0.7890342739620343}. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 14:00:22,845] Trial 984 finished with value: 0.7557698772428405 and parameters: {'num_iterations': 1025, 'learning_rate': 0.009725626431111288, 'num_leaves': 6, 'max_depth': 11, 'min_data_in_leaft': 7, 'max_int': 370, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.4251067328125401}. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 14:00:26,866] Trial 985 finished with value: 0.7567893417565371 and parameters: {'num_iterations': 801, 'learning_rate': 0.005809661151411345, 'num_leaves': 6, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 385, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.30028757025859987}. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 14:00:31,477] Trial 986 finished with value: 0.7536431695357434 and parameters: {'num_iterations': 1130, 'learning_rate': 0.007564389417089942, 'num_leaves': 6, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 395, 'min_data_in_bin': 22, 'bagging_fraction': 1.0, 'neg_bagging_fraction': 0.6029693271478288}. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 14:00:35,458] Trial 987 finished with value: 0.7515583426560355 and parameters: {'num_iterations': 923, 'learning_rate': 1.0899641403349434e-05, 'num_leaves': 7, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 390, 'min_data_in_bin': 22, 'bagging_fraction': 0.7000000000000001, 'neg_bagging_fraction': 0.9235157235647168}. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 14:00:39,837] Trial 988 finished with value: 0.7570012347795332 and parameters: {'num_iterations': 1043, 'learning_rate': 0.004732087012470873, 'num_leaves': 6, 'max_depth': 12, 'min_data_in_leaft': 7, 'max_int': 380, 'min_data_in_bin': 22, 'bagging_fraction': 0.8, 'neg_bagging_fraction': 0.6878715117992052}. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 14:00:44,278] Trial 989 finished with value: 0.7512601163689844 and parameters: {'num_iterations': 952, 'learning_rate': 1.7179218667901124e-05, 'num_leaves': 6, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 390, 'min_data_in_bin': 22, 'bagging_fraction': 0.9, 'neg_bagging_fraction': 0.750748359858701}. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 14:00:49,869] Trial 990 finished with value: 0.7511115714107783 and parameters: {'num_iterations': 1200, 'learning_rate': 1.0464613548689017e-05, 'num_leaves': 6, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 375, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.6919768893398329}. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 14:00:54,960] Trial 991 finished with value: 0.7566247715541153 and parameters: {'num_iterations': 1129, 'learning_rate': 0.003681071341933862, 'num_leaves': 6, 'max_depth': 10, 'min_data_in_leaft': 5, 'max_int': 390, 'min_data_in_bin': 22, 'bagging_fraction': 0.7000000000000001, 'neg_bagging_fraction': 0.8210890815480038}. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 14:00:58,670] Trial 992 finished with value: 0.7526820444102347 and parameters: {'num_iterations': 930, 'learning_rate': 0.0006101066991854984, 'num_leaves': 6, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 370, 'min_data_in_bin': 19, 'bagging_fraction': 0.9, 'neg_bagging_fraction': 0.885693563321714}. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 14:01:02,664] Trial 993 finished with value: 0.7514794814654223 and parameters: {'num_iterations': 939, 'learning_rate': 0.00010607913005207204, 'num_leaves': 6, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 380, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.533907442522917}. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 14:01:06,735] Trial 994 finished with value: 0.7534887140683824 and parameters: {'num_iterations': 874, 'learning_rate': 0.0010303611865505162, 'num_leaves': 6, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 385, 'min_data_in_bin': 22, 'bagging_fraction': 1.0, 'neg_bagging_fraction': 0.954521628615926}. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 14:01:10,564] Trial 995 finished with value: 0.7543120501224323 and parameters: {'num_iterations': 911, 'learning_rate': 0.001683315979753903, 'num_leaves': 5, 'max_depth': 11, 'min_data_in_leaft': 7, 'max_int': 390, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.8188894946409623}. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 14:01:15,092] Trial 996 finished with value: 0.7533245797034549 and parameters: {'num_iterations': 958, 'learning_rate': 0.0008829287089779476, 'num_leaves': 6, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 380, 'min_data_in_bin': 22, 'bagging_fraction': 0.9, 'neg_bagging_fraction': 0.8636664042788174}. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 14:01:18,995] Trial 997 finished with value: 0.7567162562530262 and parameters: {'num_iterations': 891, 'learning_rate': 0.004244899791910518, 'num_leaves': 6, 'max_depth': 11, 'min_data_in_leaft': 8, 'max_int': 395, 'min_data_in_bin': 22, 'bagging_fraction': 0.8, 'neg_bagging_fraction': 0.36195815918954255}. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 14:01:22,774] Trial 998 finished with value: 0.7568518089963655 and parameters: {'num_iterations': 834, 'learning_rate': 0.0053990550338383035, 'num_leaves': 6, 'max_depth': 11, 'min_data_in_leaft': 6, 'max_int': 375, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.7985369331585396}. Best is trial 798 with value: 0.757862329131255.
# [I 2023-05-10 14:01:27,150] Trial 999 finished with value: 0.7564039663639519 and parameters: {'num_iterations': 944, 'learning_rate': 0.006164742158023356, 'num_leaves': 6, 'max_depth': 12, 'min_data_in_leaft': 7, 'max_int': 370, 'min_data_in_bin': 22, 'bagging_fraction': 0.6000000000000001, 'neg_bagging_fraction': 0.557258137499719}. Best is trial 798 with value: 0.757862329131255.
# Best trial
# Avg of five fold auc:0.757862
# Params
# num_iterations:953
# learning_rate:0.004580578839323919
# num_leaves:6
# max_depth:11
# min_data_in_leaft:6
# max_int:380
# min_data_in_bin:22
# bagging_fraction:0.6000000000000001
# neg_bagging_fraction:0.20589882762815556

# %%
param = {'num_iterations':995, 'learning_rate':0.00471212286205368, 'num_leaves':5,' max_depth':11, 'min_data_in_leaf':7
        ,'max_bin':405, 'min_data_in_bin':19, 'objective':'binary', 'feature_fraction':0.3, 'verbosity':0, 'force_col_wise':True, 
         'bagging_fraction':0.6, 'neg_bagging_fraction':0.3693772602188242, 'linear_tree':True, 'seed':42}
train_x, train_y = train.drop(['order_status_key', 'fold'], axis=1), train['order_status_key']
dtrain = lgbm.Dataset(train_x, label=train_y)
clf = lgbm.train(param, dtrain, categorical_feature=['degree', 'card_num', 'gender'])
clf.save_model(config.LIGHTGBM)

# %% [markdown]
# ## learning curve

# %%
train = pd.read_csv(config.TRAIN)
train_x, train_y = train.drop(['order_status_key', 'fold'], axis=1), train['order_status_key']
lr_param = {'C':1, 'max_iter':20, 'solver':'newton-cg', 'class_weight':'balanced'}
rf_param = {'n_estimators':358, 'criterion':'entropy', 'max_depth':9, 'min_samples_split':35, 'min_samples_leaf':3, \
         'max_features':0.2,'n_jobs':-1, 'random_state':42, 'class_weight':'balanced', 'max_samples':0.4}
lr = LogisticRegression(**lr_param)
rf= RandomForestClassifier(**rf_param)
common_params = {
    "X": train_x,
    "y": train_y,
    "train_sizes": np.linspace(0.1, 1.0, num=10),
    "cv": StratifiedKFold(n_splits=5, shuffle=True, random_state=42),
    "score_type": "both",
    "n_jobs": 4,
    "line_kw": {"marker": "o"},
    "std_display_style": "fill_between",
    "score_name": "roc_auc",
}

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 6))
for ax_idx, estimator in enumerate([lr, rf]):
    LearningCurveDisplay.from_estimator(estimator, **common_params, ax=ax[ax_idx])
    ax[ax_idx].set_title(f"learning curve for {estimator.__class__.__name__}")

# %% [markdown]
# 通过分析学习曲线可知，增加训练样本不能改善样本性能，下一步的精力应该放在改善模型/特征工程/收集更多特征上
